# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandasql as ps
import mysql.connector as ms

import warnings
warnings.filterwarnings('ignore')

# %%
import random

# %%
df_info_clients = pd.read_csv('data/clients_informations.csv')
df_info_clients.head()
# Out:
#    amostra                        id_cliente  \
# 0        0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1        1  8912fc0c3bbf1e2fbf35819e21706718
# 2        2  8912fc0c3bbf1e2fbf35819e21706718
# 3        3  f0ac8e5a239118859b1734e1087cbb1f
# 4        4  6bc8d08963a135220ed6c6d098831f84
#
#                    id_unico_cliente  item_id  cep_cliente   cidade_cliente  \
# 0  861eff4711a542e4b93843c6dd7febb0        1        14409           franca
# 1  9eae34bbd3a474ec5d07949ca7de67c0        1        68030         santarem
# 2  9eae34bbd3a474ec5d07949ca7de67c0        2        68030         santarem
# 3  3c799d181c34d51f6d44bbbc563024db        1        92480  nova santa rita
# 4  23397e992b09769faf5e66f9e171a241        1        25931             mage
#
#   estado_cliente                         id_pedido status_pedido  \
# 0             SP  00e7ee1b050b8499577073aeb2a297a1     delivered
# 1             PA  c1d2b34febe9cd269e378117d6681172     delivered
# ...

# %%
df_info_clients['preco'] = df_info_clients.apply(lambda row: random.randint(100, 110000)/100, axis=1)

# %%
df_info_clients['pagamento_valor'] = df_info_clients['preco'] + df_info_clients['frete']

# %%
from datetime import datetime, timedelta

# %%
start_date = datetime(2019, 1, 1)
end_date = datetime(2022, 12, 31)

# %%
df_info_clients['horario_pedido'] = df_info_clients.apply(
    lambda row: start_date + timedelta(days=random.randint(0, (end_date - start_date).days)), axis=1)

# %%
df_info_clients.head()
# Out:
#    amostra                        id_cliente  \
# 0        0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1        1  8912fc0c3bbf1e2fbf35819e21706718
# 2        2  8912fc0c3bbf1e2fbf35819e21706718
# 3        3  f0ac8e5a239118859b1734e1087cbb1f
# 4        4  6bc8d08963a135220ed6c6d098831f84
#
#                    id_unico_cliente  item_id  cep_cliente   cidade_cliente  \
# 0  861eff4711a542e4b93843c6dd7febb0        1        14409           franca
# 1  9eae34bbd3a474ec5d07949ca7de67c0        1        68030         santarem
# 2  9eae34bbd3a474ec5d07949ca7de67c0        2        68030         santarem
# 3  3c799d181c34d51f6d44bbbc563024db        1        92480  nova santa rita
# 4  23397e992b09769faf5e66f9e171a241        1        25931             mage
#
#   estado_cliente                         id_pedido status_pedido  \
# 0             SP  00e7ee1b050b8499577073aeb2a297a1     delivered
# 1             PA  c1d2b34febe9cd269e378117d6681172     delivered
# ...

# %%
df_info_clients['pedido_aprovado'] = df_info_clients['horario_pedido'] + df_info_clients.apply(lambda row: timedelta(days=random.randint(0, 2)), axis=1)

# %%
df_info_clients['pedido_entregador'] = df_info_clients['pedido_aprovado']+ df_info_clients.apply(lambda row: timedelta(days=random.randint(1, 7)), axis=1)

# %%
df_info_clients['pedido_entregue'] = df_info_clients['pedido_entregador'] + df_info_clients.apply(lambda row: timedelta(days=random.randint(3, 45)), axis=1)

# %%
df_info_clients['data_estimada'] = df_info_clients['pedido_entregador'] + timedelta(30)

# %%
#colocando outliers aletoriamente 
for i in range(500):
    numero = random.randint(0, len(df_info_clients))
    df_info_clients.iloc[numero,12] = df_info_clients.iloc[numero,12] +  timedelta(days=random.randint(0, 50))
    i = i +1

# %%
df_info_clients[(df_info_clients['data_estimada']-df_info_clients['pedido_entregue']).dt.days<-50]['review'] = df_info_clients.apply(lambda row: random.randint(1, 2), axis=1)

# %%
df_info_clients[(df_info_clients['data_estimada']-df_info_clients['pedido_entregue']).dt.days>50]['review'] = df_info_clients.apply(lambda row: random.randint(1, 2), axis=1)

# %%
df_info_clients[(df_info_clients['data_estimada']-df_info_clients['pedido_entregue']).dt.days>20]['review'] = df_info_clients.apply(lambda row: random.randint(3, 5), axis=1)

# %%
# filter DataFrame to only include rows with 'client_id' in id_good_clients
good_clients = df_info_clients['id_cliente'].isin(id_good_clients)

# update 'review' column for rows with 'client_id' in id_good_clients
df_info_clients.loc[good_clients, 'review'] = df_info_clients[good_clients].apply(lambda row: random.randint(4, 5), axis=1)

# %%
df_info_clients.to_csv("clien_info_right.csv")
